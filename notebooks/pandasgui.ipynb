# %%
import pandas as pd
import numpy as np
from pandasgui import show

# %%
diabetes = pd.read_csv('data/diabetes.csv')
gui = show(diabetes)
# Out:
# PandasGUI INFO — numexpr.utils — NumExpr defaulting to 4 threads.
# PandasGUI ERROR — pandasgui.store — name 'pregnancies' is not defined
# Traceback (most recent call last):
#   File "C:\Users\yuka\Anaconda3\lib\site-packages\pandas\core\computation\scope.py", line 187, in resolve
#     return self.resolvers[key]
#   File "C:\Users\yuka\Anaconda3\lib\collections\__init__.py", line 914, in __getitem__
#     return self.__missing__(key)            # support subclasses that define __missing__
#   File "C:\Users\yuka\Anaconda3\lib\collections\__init__.py", line 906, in __missing__
#     raise KeyError(key)
# KeyError: 'pregnancies'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yuka\Anaconda3\lib\site-packages\pandas\core\computation\scope.py", line 198, in resolve
#     return self.temps[key]
# KeyError: 'pregnancies'
#
# During handling of the above exception, another exception occurred:
#
# ...
